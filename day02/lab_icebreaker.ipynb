# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# dataframe - df
df = pd.read_csv('https://raw.githubusercontent.com/BolunDai0216/nyuMLSummerSchool/master/day02/Icebreaking_Dataset.csv')
df = df.dropna()

# %%
df.head(31)
# Out:
#         First             Last Grade                   City  \
# 0       Lucca         Quintela  12th      Mountain View, CA
# 1   Alexander             Anca  10th  Little Rock, Arkansas
# 2      Serena            Huang  11th             Oviedo, FL
# 3      Graham            Smith  11th      Breinigsville, PA
# 4       Maxim             Hutz  11th        Cold Spring, NY
# 5       Dylan            Bober  11th          Hollywood, FL
# 6     Leticia  Barbieri Stroeh  11th  Campinas, SP - Brazil
# 7       Ameil         Cherisme  11th           New York, NY
# 8       Sonia       Lyakhovich  11th           Brooklyn, NY
# 9      Ariana       Arabadjiev  10th           New York, NY
# 10    Anushka      Chakrabarti  11th           Princeton NJ
# 11     Corina           Torres  12th            Wyckoff, NJ
# 12     Gelila          Yimtatu  12th          Annandale, VA
# 13     Gerard          Spooner  12th           Stamford, CT
# 14     Aarush              Raj  11th        Livingston, NJ
# 16       Riya            Patel  11th             Monroe, NJ
# 17      Anish            Kumar  12th             Nutley, NJ
# 19     Thomas        Pequegnot  11th        Eastchester, NY
# 20      Aiden       McComiskey   9th              Greenwich
# 21     Steven           Oliner  12th         Glen Ridge, NJ
# 22        Noa           Morris  12th           New York, NY
# 23    Malaika            Kumar  10th            Memphis, TN
# 24     Joshua        Berkowitz  11th           New York, NY
# 25    Junchen               Wu   9th               Shanghai
#
#                                         Movie  IMDB Score       Genre  \
# 0                                       Borat         7.3      Comedy
# 1                                Interstellar         8.6      Sci-Fi
# 2                                  The Report         7.2  Historical
# 3                                Interstellar         8.6      Sci-Fi
# 4                                  The Matrix         8.7      Action
# 5                               The Godfather         9.2       Crime
# 6   Harry Potter and the Prisioner of Azkaban         7.9   Adventure
# 7              Spiderman Into the Spiderverse         8.4      Action
# 8                          The Breakfast Club         7.9      Comedy
# 9                             My Cousin Vinny         7.6      Comedy
# 10                   The Fast and the Furious         6.8      Action
# 11                                  Midsommar         7.1       Drama
# 12                         MHA: Heroes Rising         8.1       Anime
# 13                         The Social Network         7.7   Biography
# 14                             Shutter Island         8.1     Mystery
# 16                                   Clueless         6.8    Romantic
# 17    Harry Potter and the Chamber of Secrets         7.4   Adventure
# 19                      Avengers Infinity War         8.4      Action
# 20                   The shawshank redemption         9.3       Drama
# 21                                   Drumline         5.8       Drama
# 22                                  Bombshell         6.8   Biography
# 23                                    The Meg         6.2      Sci-Fi
# 24                          Good Will Hunting         8.3      Drama
# 25                                Ratatouille         8.0   Adventure
#
#     Coding experience        Programming language
# 0                 2.0                  Python, JS
# 1                 1.0        Python, JS, HTML/CSS
# 2                 4.0      Python, Java, HTML/CSS
# 3                 4.0   Python, C++, JS, HTML/CSS
# 4                 3.0        Python, C, C++, Java
# 5                 4.0  JS, Python, HTML/CSS, Java
# 6                 3.5                C, C++, HTML
# 7                 2.0                   Python, C
# 8                 1.5           (learning) Python
# 9                 2.5                      Python
# 10                3.0            Java, JavaScript
# 11                3.0    Python, JavaScript, HTML
# 12                3.0    Python, JavaScript, Java
# 13                3.0          Python, Java, HTML
# 14                4.0   Java, Python, HTML, Swift
# 16                4.0                     Java, C
# 17                4.0      Java, Python, HTML/CSS
# 19                2.0                      Python
# 20                2.5                 Python, Lua
# 21                4.0           Python, Some Java
# 22                2.5            Python, HTML/CSS
# 23                2.0                      Python
# 24                3.0        JS, HTML, CSS, Swift
# 25                2.5                        Java

# %%
names = df['Movie'].values
score = df['IMDB Score'].values

# %% [markdown]
# ### Plot the IMDB scores for all the movies
# - Use the [plt.scatter() function](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.scatter.html)
# - x-axis indicates the name of the movies, y-axis shows the score.
# - do not forget to put on the labels for the axes.

# %%
## To-do

# %% [markdown]
# ### Plot the number of movies for each genre
# - Use the [plt.bar() function](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.bar.html)
# - x-axis indicates the genre, y-axis shows the count for each genre.
# - do not forget to put on the labels for the axes.

# %%
# To-do

# %% [markdown]
# ### Plot the histogram for the IMDB score
# - Use [plt.hist() function](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.hist.html)
# - x-axis indicates the score interval, y-axis shows the number of movies within each score interval
# - make the interval length 0.5
# - do not forget to put on the labels for the axes.

# %% [markdown]
# - numpy arange() might come in handy!

# %%
# To-do

# %% [markdown]
# ### Calculate the mean and variance of the IMDB score of the movies

# %%
# To-do
